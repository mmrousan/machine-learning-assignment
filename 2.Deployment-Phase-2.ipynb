# %%
#This is the Deployment phase
#We create a new Jupyter Notebook named as "2.Deployment-Phase-2",
# and save it in the same folder as the trained model file.
## We then import the pickle library to load the saved model.

# %%
import pickle

# %%
# Load the previously trained and saved model.
# Create a variable called "loaded_model" to store the loaded model.
# Provide 0 years of experience as the new input.
# Use the loaded model to predict the salary.
# Store the predicted salary in a variable called "result".

# %%
loaded_model=pickle.load(open("findlized_model_linear.sav",'rb'))
result=loaded_model.predict([[0]])
# Out:
# C:\Users\rousan\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#First, we load the saved model into the loaded_model variable. 
#Then, we provide 0 years of experience to the model. 
#The model predicts the corresponding salary and stores it in the result variable.

# %%
# Display the predicted salary.

# %%
result
# Out:
# array([[26777.3913412]])

# %%
#We loaded the saved model and entered 0 years of experience. 
#Since the experience value is zero, the weight multiplied by zero becomes zero. 
#Therefore, the predicted salary is equal to the bias, which is approximately 26,777.39.

# %%
#Y=9360 * X+ 26777
#Y= 9360 * 0 + 26777
#26777
